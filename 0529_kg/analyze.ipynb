# %%
import os
print(os.getcwd())
# Out:
# /home/ftk3187/github/PSED/0529_kg

# %%
import os, runpy
os.chdir('/home/ftk3187/github/PSED/0529_kg')  # 프로젝트 루트
runpy.run_path('analyze_01_coverage.py', run_name='__main__')
# Out:
# Papers analyzed: 5
#   - Aguinsky et al. - 2023 - Modeling incomplete conformality du
#   - Arts et al. - 2019 - Sticking probabilities of H2O and Al(CH
#   - Yanguas-Gil and Elam - 2012 - Simple model for atomic layer
#   - Yim et al. - 2020 - Saturation profile based conformality an
#   - Ylilammi et al. - 2018 - Modeling growth kinetics of thin fi
#
# ...
#   TRANSPORT SCHEMA  (n=5)
# ...
#
#   ✅ Always filled (69 fields)
#      diffusion_model.coefficients.effective_diffusion_coefficient.annotation
#      related_variables.diffusion_coefficient.units
#      regime_indicators.pressure.physical_meaning
#      equation_structure.time_dependence
#      diffusion_model.coefficients.effective_diffusion_coefficient.units
#      transport_variable.canonical_name
#      diffusion_model.coefficients.effective_diffusion_coefficient.definition
#      related_variables.diffusion_coefficient.paper_symbol
#      diffusion_model.coefficients.molecular_diffusion_coefficient.units
# ...
